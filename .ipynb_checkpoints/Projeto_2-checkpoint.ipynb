# %% [markdown]
# # Projeto 2 - Ciência dos Dados
#
#
#
# **Grupo:** Daniel Parnes, Luca Oshiro Camargo e Tomás Selaibe Pires - Turma C

# %% [markdown]
# <div id="indice"></div>
#
# ## Índice
#
# - [Introdução](#introducao)
#     - [Apresentação e Objetivos](#apreobs)
#     - [Bibliotecas e base de dados](#bibliobase)
#     - [Base de dados](#database)
#
# - [Limpeza  e Análise Exploratória](#limpexp)
#     - [Criando base de teste e treinamento](#testtrain)
#     - [Análise Exploratória](#analise)
#
# - [Referências](#referencias)
#
# ___

# %% [markdown]
# <div id="introducao"></div>
#
# ## Introdução
# <div id="apreobs"></div>
#
# ### Apresentação e Objetivos
#
# A Ciência dos dados é uma área voltada para o estudo e a análise de dados dos mais variados tipos. Por combinar vários campos, essa área de conhecimento pode abordar dados econômicos, sociais e estatísticos, dentre outros, visando adquirir algum conhecimento sobre padrões e/ou variáveis que permitam uma possível tomada de decisão. Em suma, a Ciência dos Dados visa estudar as informações e seus processos de captura, transformação, geração e análise de dados.
#
# Nos dias de hoje, com a maior disseminação das redes virtuais, fazemos parte de um grande ecossistema de dados e somos responsáveis por um gigantesco fluxo de informações digitais. Dessa maneira, a Ciência dos Dados se torna de grande importância para que seja possível tratar e estudar esse grande fluxo de dados, sendo possível tomar decisões inteligentes e coerentes a favor de resultados que beneficiem quem os estuda. Por isso, a Ciência dos Dados se torna uma ferramenta de grande importância para empresas e analistas econômicos (por exemplo) para que seja possível entender melhor a sua clientela, otimizando a sua atuação no mercado.
#
# Partindo dessa breve descrição do que é a Ciência dos Dados, o objetivo deste projeto é de prever o comportamento de uma varíavel target, também chamada de variável dependente ou resposta, com base em certas features, ou variáveis independentes. Para isso, o grupo escolheu como tema deste Projeto, prever o **preço de um automóvel no mercado de usados** com base em suas características, como motorização, consumo de combustível, ano que foi produzido, dente outras. Isso é algo interessante, pois além de mostrar a abrangência da Ciência dos Dados e também por ser uma ferramenta muito útil para quem está procurando comprar um veículo e quer estimar seu preço com base em suas características.
#
# Como os dados a serem analisados são quantitativos, utilizaremos modelos de regressão para realizar a previsão dos dados. Além disso, a base de dados utilizada corresponde à um compilado de veículos anunciados no site de vendas de veículos CarDekho, cuja atuação é predominante na Índia e foi obtida na plataforma digital Kaggle[1], um grande centro da comunidade de Ciência dos Dados internacional. A base de dados, atualizada poucas semanas antes do início da produção deste Projeto, fornece diversas características de cada carro listado e o preço que está sendo anunciado.

# %% [markdown]
# <div id="biblio"></div>
#
# ### Bibliotecas
#
# Para iniciar o desenvolvimento do projeto, devemos primeiramente importar algumas bibliotecas essenciais. Para as operações com a base de dados, utilizaremos a biblioteca Pandas, uma ferramenta poderosa, flexível e simples para manipulação e análise de dados, desenvolvida sobre a linguagem de programação Python. Além disso, também utilizaremos a biblioteca de análise preditiva de dados Scikit-Learn (sklearn)[2], da qual extrairemos algumas funções para geração dos modelos de regressão[3] e, para a exibição dos dados e operações numéricas, utilizaremos as bilbiotecas matplotlib.pyplot[4] e numpy[5], respectivamente. Além disso, utilizaremos a biblioteca Seaborn[6] para produzir comparações visuais entre as variáveis. Todas as bibliotecas que serão utilizadas no projeto estão inseridas na célula abaixo, de forma a facilitar e tornar mais fluida a leitura do trabalho, não havendo necessidade de rodar células extras posteriormente.

# %%
#Bibliotecas

# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import os
import sklearn.model_selection as skms
from sklearn.model_selection import train_test_split
import seaborn as sns
import statsmodels.api as sm
from sklearn.tree import DecisionTreeRegressor
from sklearn.metrics import r2_score
from sklearn.tree import DecisionTreeRegressor
from sklearn import tree
from sklearn.datasets import load_iris


from mpl_toolkits.mplot3d import Axes3D
from IPython.display import display

# %% [markdown]
# <div id="database"></div>
#
# ### Base de Dados

# %% [markdown]
# Além de importarmos as bibliotecas necessárias, é preciso que a base de dados esteja pronta para ser utilizada e inserida na mesma pasta deste arquivo. Para isso, a célula abaixo verifica se o diretório da base de dados é o mesmo do arquivo.

# %%
filename = 'cardetails.xlsx'
if filename in os.listdir():
    print(f'Encontrei o arquivo {filename}, tudo certo para prosseguir com o desenvolvimento do projeto!')
else:
    print(f'Não encontrei o arquivo {filename} aqui no diretório {os.getcwd()}, será que ele foi baixado corretamente?')
# Out:
# Encontrei o arquivo cardetails.xlsx, tudo certo para prosseguir com o desenvolvimento do projeto!

# %% [markdown]
# Encontrada a base de dados, podemos seguir com o desenvolvimento do projeto! Antes, porém, devemos saber um pouco mais sobre o conteúdo da base de dados que iremos utilizar, por isso, a tabela abaixo descreve o conteúdo de cada uma das colunas dos dados.

# %% [markdown]
# Variável | Descrição
# :---:|---:
# name | marca e modelo do veículo
# year | ano do modelo
# selling_price | preço anunciado do modelo
# km_drivem | quilometros rodados pelo veículo
# fuel | tipo de combustível utilizado
# seller_type | vendedor
# transmissão | tipo da transmissão do veículo
# owner | proprietário do veículo
# mileage | consumo de combustível
# engine | volume do motor
# max_power | potência máxima do veículo
# torque | torque do motor
# seats | número de lugares do veículo

# %% [markdown]
# Esse primeiro contato com o tipo de informação contida na base de dados é importante pois já nos da uma ideia de quais limpezas e operações precisaremos fazer antes de iniciarmos a exploração dos dados. Por exemplo, como estamos lidando com um target quantitativo, ou seja, o preço do automóvel, devemos trabalhar apenas com variáveis quantitativas, preferencialmente. Dessa forma, qualquer variável qualitativa presente na base de dados deve ser transformada em uma variável dummy, que será abordado mais adiante.
#
# Vamos, então, analisar como cada coluna está organizada, de forma a conferir quais colunas necessitarão de retrabalhos, como limpeza de caracteres não desejados ou transformação em dummies. Além disso, utilizando a função `.dtypes` do pandas, podemos saber quais os tipos de dados que cada coluna possui (float, object, int, category, etc)

# %%
dados = pd.read_excel(filename)
dados.head(5)
# Out:
#                            name  year  selling_price  km_driven    fuel  \
# 0        Maruti Swift Dzire VDI  2014         450000     145500  Diesel
# 1  Skoda Rapid 1.5 TDI Ambition  2014         370000     120000  Diesel
# 2      Honda City 2017-2020 EXi  2006         158000     140000  Petrol
# 3     Hyundai i20 Sportz Diesel  2010         225000     127000  Diesel
# 4        Maruti Swift VXI BSIII  2007         130000     120000  Petrol
#
#   seller_type transmission         owner     mileage   engine   max_power  \
# 0  Individual       Manual   First Owner   23.4 kmpl  1248 CC      74 bhp
# 1  Individual       Manual  Second Owner  21.14 kmpl  1498 CC  103.52 bhp
# 2  Individual       Manual   Third Owner   17.7 kmpl  1497 CC      78 bhp
# 3  Individual       Manual   First Owner   23.0 kmpl  1396 CC      90 bhp
# 4  Individual       Manual   First Owner   16.1 kmpl  1298 CC    88.2 bhp
#
#                      torque  seats
# 0            190Nm@ 2000rpm    5.0
# ...

# %%
dados.dtypes
# Out:
# name              object
# year               int64
# selling_price      int64
# km_driven          int64
# fuel              object
# seller_type       object
# transmission      object
# owner             object
# mileage           object
# engine            object
# max_power         object
# torque            object
# seats            float64
# dtype: object

# %% [markdown]
# Além de analisar visualmente os dados, devemos utilizar a função `.describe`, também do pandas, para saber o número de linhas, a média de cada coluna (somente das colunas que possuem variáveis quantitativas, já que não é possível saber uma média entre duas palavras, não é mesmo?), o desvio padrão dessas colunas, o valor mínimo, máximo e os quartis (os quartis, na estatística, são os valores que dividem o conjunto de dados em quatro partes iguais).

# %%
dados.describe()
# Out:
#               year  selling_price     km_driven        seats
# count  8128.000000   8.128000e+03  8.128000e+03  7907.000000
# mean   2013.804011   6.382718e+05  6.981951e+04     5.416719
# std       4.044249   8.062534e+05  5.655055e+04     0.959588
# min    1983.000000   2.999900e+04  1.000000e+00     2.000000
# 25%    2011.000000   2.549990e+05  3.500000e+04     5.000000
# 50%    2015.000000   4.500000e+05  6.000000e+04     5.000000
# 75%    2017.000000   6.750000e+05  9.800000e+04     5.000000
# max    2020.000000   1.000000e+07  2.360457e+06    14.000000

# %% [markdown]
# Agora que temos um panorama inicial dos dados (informações de cada coluna e descrição da base de dados) devemos checar por dados em branco antes de fazer qualquer manipulação na base de dados. Os dados nulos são comuns em aglomerados muito grandes de informação, já que pode acontecer de uma informação não ter sido registrada, por exemplo, na catalogação de um veículo ao entrar no site de vendas. Para isso, utilizaremos a função `.isnull().any()` do pandas que retorna um valor booleano caso haja algum valor vazio na coluna. Além disso, a função `.isnull().sum()` retorna o número de valores em branco de cada coluna.

# %%
dados.isnull().any()
# Out:
# name             False
# year             False
# selling_price    False
# km_driven        False
# fuel             False
# seller_type      False
# transmission     False
# owner            False
# mileage           True
# engine            True
# max_power         True
# torque            True
# seats             True
# dtype: bool

# %%
dados.isna().sum()
# Out:
# name               0
# year               0
# selling_price      0
# km_driven          0
# fuel               0
# seller_type        0
# transmission       0
# owner              0
# mileage          221
# engine           221
# max_power        215
# torque           222
# seats            221
# dtype: int64

# %% [markdown]
# É possível perceber que ambas as funções identificaram a existência de valores nulos em algumas colunas vazias. Por isso, precisamos analisar se a retirada desses valores irá influenciar de alguma forma as análises exploratórias futuras. Primeiramente, devemos retirar os valores nulos da base de dados utilizando a função `.dropna()`que irá deletar toda e qualquer linha que possuir algum valor vazio. Em seguida, devemos executar um segundo describe e compará-lo com o describe executado com a base de dados completa.

# %%
dados = dados.dropna()
dados.describe()
# Out:
#               year  selling_price     km_driven        seats
# count  7906.000000   7.906000e+03  7.906000e+03  7906.000000
# mean   2013.983936   6.498137e+05  6.918866e+04     5.416393
# std       3.863695   8.135827e+05  5.679230e+04     0.959208
# min    1994.000000   2.999900e+04  1.000000e+00     2.000000
# 25%    2012.000000   2.700000e+05  3.500000e+04     5.000000
# 50%    2015.000000   4.500000e+05  6.000000e+04     5.000000
# 75%    2017.000000   6.900000e+05  9.542500e+04     5.000000
# max    2020.000000   1.000000e+07  2.360457e+06    14.000000

# %% [markdown]
# Comparando as descrições da base de dados antes e depois da remoção das linhas com valores nulos, percebemos que a diferença entre eles era proporcionalmente pequena. Vimos que o preço médio após a remoção dos valores vazios aumentou e a quilometragem rodada média diminuiu, indicando que os carros removidos eram de menor valor e mais rodados. Como o número de carros removidos representa em torno de 3% da base de dados e tendo os pontos mencionados acima em mente, podemos removê-los da base de dados. Além disso, a baixa variação nos valores deste segundo describe nos mostra que os dados retirados não apresentam nenhum padrão específico, não comprometendo a amostra.
#
# Feito isso, podemos seguir para o próximo passo do Projeto: a limpeza da base de dados e a análise exploratória dos dados. Esse passo consiste basicamente em fazer as adaptações necessária nos dados, seja limpando caracteres indesejados ou mudando o tipo de uma variável e, posteriormente, analisar as relações existentes entre as variáveis independentes e o target.

# %% [markdown]
# <div id="limpexp"></div>
#
# # Limpeza  e Análise Exploratória

# %% [markdown]
# Como foi dito anteriormente, nesse passo iremos realizar as manipulações necessárias para que seja possível tirar alguma conclusão da nossa base de dados. Primeiramente, como temos diversar variáveis qualitativas, devemos transformá-las em variáveis dummy.
#
# Uma variável dummy é aquela que toma valor 0 ou 1 para indicar a falta ou presença de um fator categórico que possa vir a mudar o resultado de uma análise. Elas podem ser vistas como representações numéricas de fatores qualitativos em um modelo de regressão, como é o caso deste projeto, dividindo uma variável em categorias opostas, como seria o caso da transmissão de um veículo: manual ou automático. A variável dummy que assume valor zero, indicará que aquela não exerce nenhum papel em influenciar o resultado do target (variável dependente). Por outro lado, quando esta assume valor 1, terá o efeito contrário.
#
# No primeiro caso de substituição por dummies, temos a coluna `seller_type`. Essa coluna, por sua vez possui 3 valores: Dealer Individual e Trustmark Dealer. Dessa forma, ao transformarmos a coluna em dummy, utilizando a função `pd.get_dummies()` do pandas, iremos criar três novas colunas, uma para cada valor distinto da coluna. Assim cada linha será associada com um valor 0 ou 1 em cada uma das colunas, sendo que se é atribuido o valor 1 a uma dessas colunas, automaticamente o valor 0 é atribuído às demais.

# %%
dummy_seller_type = pd.get_dummies(dados['seller_type'])
dummy_seller_type.head()
# Out:
#    Dealer  Individual  Trustmark Dealer
# 0       0           1                 0
# 1       0           1                 0
# 2       0           1                 0
# 3       0           1                 0
# 4       0           1                 0

# %% [markdown]
# Criadas as dummies, agora precisamos anexá-las à base de dados utilizando a função `pd.concat()` abaixo.

# %%
dados = pd.concat([dados, dummy_seller_type], axis=1)
dados.head()
# Out:
#                            name  year  selling_price  km_driven    fuel  \
# 0        Maruti Swift Dzire VDI  2014         450000     145500  Diesel
# 1  Skoda Rapid 1.5 TDI Ambition  2014         370000     120000  Diesel
# 2      Honda City 2017-2020 EXi  2006         158000     140000  Petrol
# 3     Hyundai i20 Sportz Diesel  2010         225000     127000  Diesel
# 4        Maruti Swift VXI BSIII  2007         130000     120000  Petrol
#
#   seller_type transmission         owner     mileage   engine   max_power  \
# 0  Individual       Manual   First Owner   23.4 kmpl  1248 CC      74 bhp
# 1  Individual       Manual  Second Owner  21.14 kmpl  1498 CC  103.52 bhp
# 2  Individual       Manual   Third Owner   17.7 kmpl  1497 CC      78 bhp
# 3  Individual       Manual   First Owner   23.0 kmpl  1396 CC      90 bhp
# 4  Individual       Manual   First Owner   16.1 kmpl  1298 CC    88.2 bhp
#
#                      torque  seats  Dealer  Individual  Trustmark Dealer
# ...

# %% [markdown]
# Agora que foi feito o processo para a primeira coluna qualitativa, precisamos repetir os mesmos passos para as colunas: `fuel`, `transmission` e `owner`.

# %%
dummy_fuel = pd.get_dummies(dados['fuel'])
dummy_fuel.head()
# Out:
#    CNG  Diesel  LPG  Petrol
# 0    0       1    0       0
# 1    0       1    0       0
# 2    0       0    0       1
# 3    0       1    0       0
# 4    0       0    0       1

# %%
dados = pd.concat([dados, dummy_fuel], axis=1)
dados.head()
# Out:
#                            name  year  selling_price  km_driven    fuel  \
# 0        Maruti Swift Dzire VDI  2014         450000     145500  Diesel
# 1  Skoda Rapid 1.5 TDI Ambition  2014         370000     120000  Diesel
# 2      Honda City 2017-2020 EXi  2006         158000     140000  Petrol
# 3     Hyundai i20 Sportz Diesel  2010         225000     127000  Diesel
# 4        Maruti Swift VXI BSIII  2007         130000     120000  Petrol
#
#   seller_type transmission         owner     mileage   engine   max_power  \
# 0  Individual       Manual   First Owner   23.4 kmpl  1248 CC      74 bhp
# 1  Individual       Manual  Second Owner  21.14 kmpl  1498 CC  103.52 bhp
# 2  Individual       Manual   Third Owner   17.7 kmpl  1497 CC      78 bhp
# 3  Individual       Manual   First Owner   23.0 kmpl  1396 CC      90 bhp
# 4  Individual       Manual   First Owner   16.1 kmpl  1298 CC    88.2 bhp
#
#                      torque  seats  Dealer  Individual  Trustmark Dealer  CNG  \
# ...

# %%
dummy_transmission = pd.get_dummies(dados['transmission'])
dummy_transmission.head()
# Out:
#    Automatic  Manual
# 0          0       1
# 1          0       1
# 2          0       1
# 3          0       1
# 4          0       1

# %%
dados = pd.concat([dados, dummy_transmission], axis=1)
dados.head()
# Out:
#                            name  year  selling_price  km_driven    fuel  \
# 0        Maruti Swift Dzire VDI  2014         450000     145500  Diesel
# 1  Skoda Rapid 1.5 TDI Ambition  2014         370000     120000  Diesel
# 2      Honda City 2017-2020 EXi  2006         158000     140000  Petrol
# 3     Hyundai i20 Sportz Diesel  2010         225000     127000  Diesel
# 4        Maruti Swift VXI BSIII  2007         130000     120000  Petrol
#
#   seller_type transmission         owner     mileage   engine   max_power  \
# 0  Individual       Manual   First Owner   23.4 kmpl  1248 CC      74 bhp
# 1  Individual       Manual  Second Owner  21.14 kmpl  1498 CC  103.52 bhp
# 2  Individual       Manual   Third Owner   17.7 kmpl  1497 CC      78 bhp
# 3  Individual       Manual   First Owner   23.0 kmpl  1396 CC      90 bhp
# 4  Individual       Manual   First Owner   16.1 kmpl  1298 CC    88.2 bhp
#
#                      torque  seats  Dealer  Individual  Trustmark Dealer  CNG  \
# ...

# %%
dummy_owner = pd.get_dummies(dados['owner'])
dummy_owner.head()
# Out:
#    First Owner  Fourth & Above Owner  Second Owner  Test Drive Car  \
# 0            1                     0             0               0
# 1            0                     0             1               0
# 2            0                     0             0               0
# 3            1                     0             0               0
# 4            1                     0             0               0
#
#    Third Owner
# 0            0
# 1            0
# 2            1
# 3            0
# 4            0

# %%
dados = pd.concat([dados, dummy_owner], axis=1)
dados.head()
# Out:
#                            name  year  selling_price  km_driven    fuel  \
# 0        Maruti Swift Dzire VDI  2014         450000     145500  Diesel
# 1  Skoda Rapid 1.5 TDI Ambition  2014         370000     120000  Diesel
# 2      Honda City 2017-2020 EXi  2006         158000     140000  Petrol
# 3     Hyundai i20 Sportz Diesel  2010         225000     127000  Diesel
# 4        Maruti Swift VXI BSIII  2007         130000     120000  Petrol
#
#   seller_type transmission         owner     mileage   engine   max_power  \
# 0  Individual       Manual   First Owner   23.4 kmpl  1248 CC      74 bhp
# 1  Individual       Manual  Second Owner  21.14 kmpl  1498 CC  103.52 bhp
# 2  Individual       Manual   Third Owner   17.7 kmpl  1497 CC      78 bhp
# 3  Individual       Manual   First Owner   23.0 kmpl  1396 CC      90 bhp
# 4  Individual       Manual   First Owner   16.1 kmpl  1298 CC    88.2 bhp
#
#                      torque  seats  Dealer  Individual  Trustmark Dealer  CNG  \
# ...

# %% [markdown]
# Agora que todas as dummies foram criadas, vamos observar o resultado deste processo na base de dados. Note como foram criadas diversas novas colunas para cada valor das colunas qualitativas.

# %%
dados.head()
# Out:
#                            name  year  selling_price  km_driven    fuel  \
# 0        Maruti Swift Dzire VDI  2014         450000     145500  Diesel
# 1  Skoda Rapid 1.5 TDI Ambition  2014         370000     120000  Diesel
# 2      Honda City 2017-2020 EXi  2006         158000     140000  Petrol
# 3     Hyundai i20 Sportz Diesel  2010         225000     127000  Diesel
# 4        Maruti Swift VXI BSIII  2007         130000     120000  Petrol
#
#   seller_type transmission         owner     mileage   engine   max_power  \
# 0  Individual       Manual   First Owner   23.4 kmpl  1248 CC      74 bhp
# 1  Individual       Manual  Second Owner  21.14 kmpl  1498 CC  103.52 bhp
# 2  Individual       Manual   Third Owner   17.7 kmpl  1497 CC      78 bhp
# 3  Individual       Manual   First Owner   23.0 kmpl  1396 CC      90 bhp
# 4  Individual       Manual   First Owner   16.1 kmpl  1298 CC    88.2 bhp
#
#                      torque  seats  Dealer  Individual  Trustmark Dealer  CNG  \
# ...

# %% [markdown]
# Vamos, então, para a segunda etapa de limpeza da base de dados: a remoção de caracteres indesejados. Isso é feito para que as variáveis quantitativas sejam vistas pelo programa como números puros, onde antes havia uma string. Nas células abaixo, foram criadas listas para guardar os valores limpos de cada uma das colunas que devemos limpar. Essa lista foi posteriormente transformada em uma nova coluna da base de dados, para que fosse possível compará-las com as colunas originais em caso de algum erro indesejado. Portanto, vamos executar as células a seguir.

# %% [markdown]
# **Limpando a coluna mileage**
#
# Nessa limpeza, retiramos a unidade dos valores das linhas, transformando-os em float e convertemos km/kg para kmpl usando a densidade média da gasolina.

# %%
mileage = []
for i in dados['mileage']:
    alvos = ["kmpl", "km/kg"]
    kmkg = 1
    if "km/kg" in i:
        kmkg = 0.7475 #Conversor pela densidade média
    for unidade in alvos:
        i = i.replace(unidade, "")
        i = i.replace(" ","")
    i = float(i)*kmkg
    mileage.append(i)
dados['mileage_num(kmpl)'] = pd.Series(mileage) #Coluna mileage limpa => numérica
dados.head()
# Out:
#                            name  year  selling_price  km_driven    fuel  \
# 0        Maruti Swift Dzire VDI  2014         450000     145500  Diesel
# 1  Skoda Rapid 1.5 TDI Ambition  2014         370000     120000  Diesel
# 2      Honda City 2017-2020 EXi  2006         158000     140000  Petrol
# 3     Hyundai i20 Sportz Diesel  2010         225000     127000  Diesel
# 4        Maruti Swift VXI BSIII  2007         130000     120000  Petrol
#
#   seller_type transmission         owner     mileage   engine   max_power  \
# 0  Individual       Manual   First Owner   23.4 kmpl  1248 CC      74 bhp
# 1  Individual       Manual  Second Owner  21.14 kmpl  1498 CC  103.52 bhp
# 2  Individual       Manual   Third Owner   17.7 kmpl  1497 CC      78 bhp
# 3  Individual       Manual   First Owner   23.0 kmpl  1396 CC      90 bhp
# 4  Individual       Manual   First Owner   16.1 kmpl  1298 CC    88.2 bhp
#
#                      torque  seats  Dealer  Individual  Trustmark Dealer  CNG  \
# ...

# %% [markdown]
# **Limpando a coluna engine**
#
# Nessa limpeza, também retiramos a unidade dos valores das linhas, transformando-os em float.

# %%
engine = []
for i in dados['engine']:
    i = i.replace('CC', "")
    i = i.replace(" ","")
    i = float(i)
    engine.append(i)
dados['engine_num(CC)'] = pd.Series(engine) #Coluna engine limpa => numérica
dados.head()
# Out:
#                            name  year  selling_price  km_driven    fuel  \
# 0        Maruti Swift Dzire VDI  2014         450000     145500  Diesel
# 1  Skoda Rapid 1.5 TDI Ambition  2014         370000     120000  Diesel
# 2      Honda City 2017-2020 EXi  2006         158000     140000  Petrol
# 3     Hyundai i20 Sportz Diesel  2010         225000     127000  Diesel
# 4        Maruti Swift VXI BSIII  2007         130000     120000  Petrol
#
#   seller_type transmission         owner     mileage   engine   max_power  \
# 0  Individual       Manual   First Owner   23.4 kmpl  1248 CC      74 bhp
# 1  Individual       Manual  Second Owner  21.14 kmpl  1498 CC  103.52 bhp
# 2  Individual       Manual   Third Owner   17.7 kmpl  1497 CC      78 bhp
# 3  Individual       Manual   First Owner   23.0 kmpl  1396 CC      90 bhp
# 4  Individual       Manual   First Owner   16.1 kmpl  1298 CC    88.2 bhp
#
#                      torque  seats  Dealer  Individual  Trustmark Dealer  CNG  \
# ...

# %% [markdown]
# **Limpando a coluna max_power**
#
# Nessa limpeza, fizemos o mesmo procedimento das demais colunas.

# %%
max_power = []
for i in dados['max_power']:
    i = i.replace('bhp', "")
    i = i.replace(" ","")
    i = float(i)
    max_power.append(i)
dados['max_power_num(bhp)'] = pd.Series(max_power) #Coluna max_power limpa => numérica
dados.head()
# Out:
#                            name  year  selling_price  km_driven    fuel  \
# 0        Maruti Swift Dzire VDI  2014         450000     145500  Diesel
# 1  Skoda Rapid 1.5 TDI Ambition  2014         370000     120000  Diesel
# 2      Honda City 2017-2020 EXi  2006         158000     140000  Petrol
# 3     Hyundai i20 Sportz Diesel  2010         225000     127000  Diesel
# 4        Maruti Swift VXI BSIII  2007         130000     120000  Petrol
#
#   seller_type transmission         owner     mileage   engine   max_power  \
# 0  Individual       Manual   First Owner   23.4 kmpl  1248 CC      74 bhp
# 1  Individual       Manual  Second Owner  21.14 kmpl  1498 CC  103.52 bhp
# 2  Individual       Manual   Third Owner   17.7 kmpl  1497 CC      78 bhp
# 3  Individual       Manual   First Owner   23.0 kmpl  1396 CC      90 bhp
# 4  Individual       Manual   First Owner   16.1 kmpl  1298 CC    88.2 bhp
#
#                      torque  seats  Dealer  Individual  Trustmark Dealer  CNG  \
# ...

# %% [markdown]
# **Limpando a coluna Torque**
#
# Nessa limpeza, também retiramos a unidade dos valores das linhas, transformando-os em float.

# %%
torque = []
for i in dados['torque']:
    fator = 1  #Conversor de Kgmf em Nm (x10 caso seja kgmf)
    if 'kg' in i and 'Nm' not in i:
        if '.' in i[:4] or ',' in i[:4]: 
            fator = 10  
    novoi = i[:3]
    alvo = ['@','N','n','m','K','k','g','(',')']
    for letra in alvo:
        novoi = novoi.replace(letra,"")
        novoi = novoi.replace(" ","")
    novoi = float(novoi)*fator
    torque.append(novoi)
dados['torque_num(Nm)'] = torque  #Coluna torque limpa => numérica
dados.head()
# Out:
#                            name  year  selling_price  km_driven    fuel  \
# 0        Maruti Swift Dzire VDI  2014         450000     145500  Diesel
# 1  Skoda Rapid 1.5 TDI Ambition  2014         370000     120000  Diesel
# 2      Honda City 2017-2020 EXi  2006         158000     140000  Petrol
# 3     Hyundai i20 Sportz Diesel  2010         225000     127000  Diesel
# 4        Maruti Swift VXI BSIII  2007         130000     120000  Petrol
#
#   seller_type transmission         owner     mileage   engine   max_power  \
# 0  Individual       Manual   First Owner   23.4 kmpl  1248 CC      74 bhp
# 1  Individual       Manual  Second Owner  21.14 kmpl  1498 CC  103.52 bhp
# 2  Individual       Manual   Third Owner   17.7 kmpl  1497 CC      78 bhp
# 3  Individual       Manual   First Owner   23.0 kmpl  1396 CC      90 bhp
# 4  Individual       Manual   First Owner   16.1 kmpl  1298 CC    88.2 bhp
#
#                      torque  seats  Dealer  Individual  Trustmark Dealer  CNG  \
# ...

# %% [markdown]
# **Criando a coluna car_age**
#
# Feitas as limpezas nas colunas quantitativas, podemos criar uma variável para computar a idade de um veículo, algo que é valorizado no mercado automotivo. Para tal, devemos criar uma nova coluna que guarda o valor da subtração entre o ano atual (2020) e o ano de fabricação do modelo

# %%
dados['car_age'] = 2020 - dados.year
dados.head()
# Out:
#                            name  year  selling_price  km_driven    fuel  \
# 0        Maruti Swift Dzire VDI  2014         450000     145500  Diesel
# 1  Skoda Rapid 1.5 TDI Ambition  2014         370000     120000  Diesel
# 2      Honda City 2017-2020 EXi  2006         158000     140000  Petrol
# 3     Hyundai i20 Sportz Diesel  2010         225000     127000  Diesel
# 4        Maruti Swift VXI BSIII  2007         130000     120000  Petrol
#
#   seller_type transmission         owner     mileage   engine   max_power  \
# 0  Individual       Manual   First Owner   23.4 kmpl  1248 CC      74 bhp
# 1  Individual       Manual  Second Owner  21.14 kmpl  1498 CC  103.52 bhp
# 2  Individual       Manual   Third Owner   17.7 kmpl  1497 CC      78 bhp
# 3  Individual       Manual   First Owner   23.0 kmpl  1396 CC      90 bhp
# 4  Individual       Manual   First Owner   16.1 kmpl  1298 CC    88.2 bhp
#
#                      torque  seats  Dealer  Individual  Trustmark Dealer  CNG  \
# ...

# %% [markdown]
# **Convertendo Rupias indianas para Dólar**
#
# Como dito no início do projeto, a base de dados contém informações do mercado automotivo indiano e, portanto, os preços estão na moeda local: a rupia. Para que seja possível uma mehlor compreensão dos valores tratados, foi realizada uma conversão de Rupia para Dólar, dado que 1 Rupia equivale a 0,013 dolares na cotação atual. Caso seja de interesse adaptar o valor do câmbio dessa moeda, basta alterar o valor da variável `rupia` na célula abaixo.

# %%
preco_dolar = []
for i in dados['selling_price']:
    rupia = 0.013
    i = i*rupia # 1 Rupia é 1,3 cents
    preco_dolar.append(i)
dados['selling_price_dollar'] = pd.Series(preco_dolar)

# %%
dados = dados.dropna() #Limpando qualquer valor vazio residual

# %%
dados.head()
# Out:
#                            name  year  selling_price  km_driven    fuel  \
# 0        Maruti Swift Dzire VDI  2014         450000     145500  Diesel
# 1  Skoda Rapid 1.5 TDI Ambition  2014         370000     120000  Diesel
# 2      Honda City 2017-2020 EXi  2006         158000     140000  Petrol
# 3     Hyundai i20 Sportz Diesel  2010         225000     127000  Diesel
# 4        Maruti Swift VXI BSIII  2007         130000     120000  Petrol
#
#   seller_type transmission         owner     mileage   engine   max_power  \
# 0  Individual       Manual   First Owner   23.4 kmpl  1248 CC      74 bhp
# 1  Individual       Manual  Second Owner  21.14 kmpl  1498 CC  103.52 bhp
# 2  Individual       Manual   Third Owner   17.7 kmpl  1497 CC      78 bhp
# 3  Individual       Manual   First Owner   23.0 kmpl  1396 CC      90 bhp
# 4  Individual       Manual   First Owner   16.1 kmpl  1298 CC    88.2 bhp
#
#                      torque  seats  Dealer  Individual  Trustmark Dealer  CNG  \
# ...

# %% [markdown]
# <div id="testtrain"></div>
#
# ### Criando base de teste e treinamento

# %% [markdown]
# Antes de iniciarmos a análise exploratória devemos realizar uma última manipulação na base de dados. Essa operação consiste em dividir a base de dados em parte de treinamento e parte de testes. Como você já deve ter imaginado, a base de treinamento é utilizada para treinar o algoritmo de previsão, ou seja, criar o modelo de regressão para que possa ser, posteriormente, aplicado sobre a base de testes para termos um resultado e um valor da porcentagem de acertos do nosso modelo. Para tal fim, utilizaremos a função `train_test_split`da biblioteca da ScikitLearn. Geralmente, separamos 70% dos dados para a base de treinamento e os 30% restantes para a base de testes, de forma a termos maior quantidade de dados para treinarmos o modelo. A função abaixo recebe como argumentos a base de dados, um valor de 0 a 1 que representa o tamanho da base de testes e um fator de aleatoriedade que será usado para embaralhar a base de dados antes de separá-la em treinamento e teste.

# %%
dados_treinamento, dados_teste = train_test_split(dados, test_size=0.30, random_state=42)

# %% [markdown]
# Feita a separação, vamos analisar as novas subdivisões da base de dados, tanto visualmente, como numericamente através da função `.describe()`

# %%
dados_treinamento.head()
# Out:
#                                          name  year  selling_price  km_driven  \
# 975                          Hyundai Getz GLS  2005          65000      85000
# 3203   Toyota Innova 2.5 GX (Diesel) 8 Seater  2016        1151000      69500
# 6629          Mahindra Bolero Pik-Up CBC 1.7T  2019         722000      80000
# 5463  Volkswagen Vento Konekt Diesel Highline  2014         575000      90000
# 4581                      Honda WR-V i-DTEC S  2017         800000      70000
#
#         fuel seller_type transmission         owner     mileage   engine  \
# 975   Petrol  Individual       Manual   First Owner   15.3 kmpl  1341 CC
# 3203  Diesel  Individual       Manual  Second Owner  12.99 kmpl  2494 CC
# 6629  Diesel  Individual       Manual   First Owner    0.0 kmpl  2523 CC
# 5463  Diesel  Individual       Manual   First Owner  20.54 kmpl  1598 CC
# 4581  Diesel  Individual       Manual   First Owner   25.5 kmpl  1498 CC
#
# ...

# %%
dados_treinamento.describe()
# Out:
#               year  selling_price     km_driven        seats       Dealer  \
# count  5381.000000   5.381000e+03  5.381000e+03  5381.000000  5381.000000
# mean   2013.993867   6.500924e+05  6.910341e+04     5.421111     0.137521
# std       3.863825   8.090900e+05  5.981408e+04     0.973416     0.344428
# min    1994.000000   3.000000e+04  1.000000e+03     2.000000     0.000000
# 25%    2012.000000   2.700000e+05  3.500000e+04     5.000000     0.000000
# 50%    2015.000000   4.550000e+05  6.000000e+04     5.000000     0.000000
# 75%    2017.000000   6.900000e+05  9.500000e+04     5.000000     0.000000
# max    2020.000000   1.000000e+07  2.360457e+06    14.000000     1.000000
#
#         Individual  Trustmark Dealer          CNG       Diesel          LPG  \
# count  5381.000000       5381.000000  5381.000000  5381.000000  5381.000000
# mean      0.832001          0.030478     0.005761     0.545438     0.005575
# ...

# %%
dados_teste.head()
# Out:
#                                         name  year  selling_price  km_driven  \
# 2469           Renault KWID 1.0 RXT Optional  2017         265000      90000
# 6721                      Renault Duster 4x4  2014         650000     129000
# 6942                      Hyundai i10 Sportz  2012         280000      65000
# 7845  Toyota Innova 2.5 E Diesel MS 7-seater  2007         626000      80000
# 5766                    Hyundai EON Era Plus  2017         310000      25000
#
#         fuel seller_type transmission         owner     mileage   engine  \
# 2469  Petrol  Individual       Manual   First Owner  23.01 kmpl   999 CC
# 6721  Diesel  Individual       Manual   First Owner  19.72 kmpl  1461 CC
# 6942  Petrol  Individual       Manual   First Owner  20.36 kmpl  1197 CC
# 7845  Diesel  Individual       Manual  Second Owner   12.8 kmpl  2494 CC
# 5766  Petrol  Individual       Manual   First Owner   21.1 kmpl   814 CC
#
# ...

# %%
dados_teste.describe()
# Out:
#               year  selling_price      km_driven        seats       Dealer  \
# count  2307.000000   2.307000e+03    2307.000000  2307.000000  2307.000000
# mean   2014.004335   6.590347e+05   69264.864759     5.420026     0.145644
# std       3.812266   8.456327e+05   49542.400632     0.942859     0.352825
# min    1994.000000   2.999900e+04    1303.000000     2.000000     0.000000
# 25%    2012.000000   2.700000e+05   34328.000000     5.000000     0.000000
# 50%    2015.000000   4.500000e+05   60000.000000     5.000000     0.000000
# 75%    2017.000000   7.000000e+05   96000.000000     5.000000     0.000000
# max    2020.000000   7.200000e+06  577414.000000    10.000000     1.000000
#
#         Individual  Trustmark Dealer          CNG       Diesel          LPG  \
# count  2307.000000       2307.000000  2307.000000  2307.000000  2307.000000
# mean      0.823147          0.031209     0.008669     0.544863     0.002167
# ...

# %% [markdown]
# É possível notar que a variação dos valores de ambos os describes é pequena (com exceção dos tamanhos de cada uma das partes). Isso acontece pois os dados foram embaralhados antes de terem sido movidos para a base de testes, quebrando qualquer padrão existente na base de dados e homogeneizando ambas as partes. Feito isso, podemos seguir para a análise exploratória.

# %% [markdown]
# <div id="analise"></div>
#
# ## Análise exploratória
#
# Nessa etapa do projeto iremos analisar as relações entre cada uma das variáveis da base de dados, tanto entre elas como com a variável target. Essa análise é realizada para encontrarmos as variáveis que  mais influenciam a variável target. Dessa forma, podemos aperfeiçoar os modelos e obter resultados mais precisos e adequados, restringindo ao modelo apenas as variáveis mais relevantes. Para isso utilizaremos, primeiramente, a função `pairplot()` da biblioteca seaborn, que produz gráficos entre todas as variáveis da base de dados. Detalhe que a célula abaixo pode levar um pouco mais de tempo para rodar que as demais.

# %%
sns.pairplot(dados,height=1.5)

# %% [markdown]
# Para otimizarmos a leitura dos gráficos acima, podemos restringir o `.pairplot()` a apenas a coluna `selling_price` e compará-la com as variáveis quantitativas que produzimos anteriormente a partir da limpeza de algumas colunas.

# %%
sns.pairplot(dados, x_vars=['year', 'km_driven', 'mileage_num(kmpl)', 'engine_num(CC)', 'max_power_num(bhp)', 'torque_num(Nm)',
       'seats', 'car_age'], y_vars=['selling_price'])

# %% [markdown]
# Como uma segunda maneira de visualizar os dados, podemos produzir um mapa de calor (heatmap). Esse nos fornece a correlação (valor numérico) entre todas as variáveis que definiremos a seguir. A correlação é uma relação estatística que envolva dependência entre duas variáveis. Em outras palavras, a correlação pode ser entendida como dependência entre duas variáveis e seu valor pode variar (em módulo, pois pode ser negativa) de 0 a 1, dado que quanto mais próximo de 1, maior a correlação entre as variáveis, ou seja, maior a dependência entre elas.
#
# Na célula abaixo, separamos a base de treinamento e teste nas váriaveis independentes `X_treinamento` e `X_teste` e nas variáveis target `Y_treinamento` e `Y_teste` para que possam ser comparadas no heatmap abaixo e nos modelos de regressão. A célula seguinte à próxima produz o mapa de calor, cuja função faz parte da biblioteca `seaborn`.

# %%
X_treinamento = dados_treinamento[['year', 'km_driven', 'mileage_num(kmpl)', 'engine_num(CC)', 'max_power_num(bhp)', 'torque_num(Nm)',
       'seats', 'car_age']]
Y_treinamento = dados_treinamento['selling_price_dollar']
X_teste = dados_teste[['year', 'km_driven', 'mileage_num(kmpl)', 'engine_num(CC)', 'max_power_num(bhp)', 'torque_num(Nm)',
       'seats', 'car_age']]
Y_teste = dados_teste['selling_price_dollar']

# %%
correlations = pd.concat([X_treinamento, pd.Series(Y_treinamento)], axis=1).corr()
    
plt.figure(figsize=(12,12))
df_corr = correlations.corr()
ax = sns.heatmap(df_corr, annot=True) #notation: "annot" not "annote"
bottom, top = ax.get_ylim()
ax.set_ylim(bottom + 0.5, top - 0.5)
plt.show()

# %% [markdown]
# **Analisando individualmente as variáveis que mostraram influenciar o preço**

# %% [markdown]
# Aqui iniciamos a função regress, que recebe 2 inputs, o Target: variável independente (Y), que será o que queremos analisar, ou seja, a variável que vamos prever, e os Features: variáveis dependentes (X), ou seja, as variáveis que se relacionam ao Y, e que fazem com que as funções importem as correlações entre as mesmas e o Y para gerar uma linha de tendência. Através de funções já implementadas em bibliotecas que importamos para realizar as contas da regressão linear, retorna-se o valor do resultado.

# %%
### Função utilitária para fazer a regressão com constante adicionada - desenvolvida em aula

def regress(Y,X):
    '''
    Y: coluna do DataFrame utilizada como variável resposta (TARGET)
    X: coluna(s) do DataFrame utilizadas como variável(is) explicativas (FEATURES)
    '''
    X_cp = sm.add_constant(X)
    model = sm.OLS(Y,X_cp)
    results = model.fit()
    
    return results

# %% [markdown]
# Abaixo, usamos a função regress na base de dados treinamento, significando que queremos prever o Y_treinamento (selling_price_dollar), através da correlação criada com as outras variáveis, em X_treinamento.
# `Resultados.summary()` é uma tabela para visualizar os valores úteis para a regressão linear.

# %%
resultados = regress(Y_treinamento,X_treinamento)
resultados.summary()
# Out:
# C:\Users\tprfe\AppData\Local\Continuum\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:2389: FutureWarning: Method .ptp is deprecated and will be removed in a future version. Use numpy.ptp instead.
#   return ptp(axis=axis, out=out, **kwargs)
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                              OLS Regression Results
# ...
# Dep. Variable:     selling_price_dollar   R-squared:                       0.591
# Model:                              OLS   Adj. R-squared:                  0.590
# Method:                   Least Squares   F-statistic:                     1107.
# Date:                  Tue, 24 Nov 2020   Prob (F-statistic):               0.00
# Time:                          14:02:22   Log-Likelihood:                -55172.
# No. Observations:                  5381   AIC:                         1.104e+05
# Df Residuals:                      5373   BIC:                         1.104e+05
# Df Model:                             7
# ...

# %% [markdown]
# **Plotando os gráficos das variáveis que aparentam influenciar no preço**
#
# A partir disso, plotamos os gráficos de selling_price_dollar, com as variáveis com alguma influência na previsão, assim é possível obter uma compreensão visual da relação entre a variável desejada e o preço para que seja possível a realização de uma melhor análise da influência de cada variável. Todos os gráficos plotados possuem o eixo X sendo o selling price em comparação com outra variável que se encontrará no eixo Y

# %% [markdown]
# **Year x Selling price**

# %%
plt.scatter(dados['year'],dados['selling_price'])
plt.title('Comparação de Ano x Preço')
plt.xlabel('Ano')
plt.ylabel('Preço')
# Out:
# Text(0, 0.5, 'Preço')

# %% [markdown]
# Aqui, apesar de aparentar uma boa correlação, é a variável com corr mais fraca, mas positiva, com selling_price_dollar, com apenas corr=0,022

# %% [markdown]
# **Km driven x selling price**

# %%
plt.scatter(dados['km_driven'],dados['selling_price'])
plt.title('Comparação de Quilometragem x Preço')
plt.xlabel('Quilometragem')
plt.ylabel('Preço')
# Out:
# Text(0, 0.5, 'Preço')

# %% [markdown]
# Esse gráfico evidencia uma corr negativa e fraca com a variável independente, apenas corr=-0,21

# %% [markdown]
# **Car agr x Selling price**

# %%
plt.scatter(dados['car_age'],dados['selling_price'])
plt.title('Comparação de Idade x Preço')
plt.xlabel('Idade')
plt.ylabel('Preço')
# Out:
# Text(0, 0.5, 'Preço')

# %% [markdown]
# O idade x preço é idêntico ao year x preço, apenas invertido, pois idade=2020-year, então conforme year cresce, idade decresce

# %% [markdown]
# **Torque x Selling price**

# %%
plt.scatter(dados['torque_num(Nm)'], dados['selling_price'])
plt.title('Comparação de Torque x Preço')
plt.xlabel('Torque')
plt.ylabel('Preço')
plt.show()

# %% [markdown]
# Intuitivamente, a potência influenciaria no preço de um carro, mas isso não é evidenciado pelo gráfico abaixo. Vamos, posteriormente, comparar uma associação da potência e torque com o preço final do carro.

# %%
plt.scatter(dados['max_power_num(bhp)'],dados['selling_price'])
plt.title('Comparação de Potência x Preço')
plt.xlabel('Potência')
plt.ylabel('Preço')
plt.show()

# %% [markdown]
# Não evidente pelo gráfico, mas a potência é a variável com maior corr com o preço, com corr=0,93, evidenciando que essa variável terá grande peso na previsão

# %% [markdown]
# **Previsão inicial**

# %% [markdown]
# Na célula abaixo, é restringido a quantidade de variáveis no X do `regress()`, para apenas aquelas que terão alguma influência na previsão da linear regression.
#
# Além disso, mais uma vez é usada a função `summary()` para encontrar os valores do coeficiente e intercepto da reta da regressão.

# %%
X_treinamento_restringido = dados_treinamento[['year','mileage_num(kmpl)','engine_num(CC)','max_power_num(bhp)', 'torque_num(Nm)','seats']]
Y_treinamento = dados_treinamento['selling_price_dollar']

resultados_treinamento = regress(Y_treinamento,X_treinamento_restringido)
resultados_treinamento.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                              OLS Regression Results
# ...
# Dep. Variable:     selling_price_dollar   R-squared:                       0.590
# Model:                              OLS   Adj. R-squared:                  0.590
# Method:                   Least Squares   F-statistic:                     1291.
# Date:                  Tue, 24 Nov 2020   Prob (F-statistic):               0.00
# Time:                          14:02:32   Log-Likelihood:                -55173.
# No. Observations:                  5381   AIC:                         1.104e+05
# Df Residuals:                      5374   BIC:                         1.104e+05
# Df Model:                             6
# Covariance Type:              nonrobust
# ...
#                          coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# ...

# %% [markdown]
# Abaixo, é feito o mesmo passo do anterior mas retirando a variável seats, que influenciava os dados de uma maneira errada, pois a correlação era muito aleatória, sem uma tendência clara.

# %%
X_treinamento_restringido = dados_treinamento[['mileage_num(kmpl)','engine_num(CC)','max_power_num(bhp)', 'torque_num(Nm)','year']]
Y_treinamento = dados_treinamento['selling_price_dollar']

resultados_treinamento = regress(Y_treinamento,X_treinamento_restringido)
resultados_treinamento.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                              OLS Regression Results
# ...
# Dep. Variable:     selling_price_dollar   R-squared:                       0.590
# Model:                              OLS   Adj. R-squared:                  0.590
# Method:                   Least Squares   F-statistic:                     1550.
# Date:                  Tue, 24 Nov 2020   Prob (F-statistic):               0.00
# Time:                          14:07:45   Log-Likelihood:                -55173.
# No. Observations:                  5381   AIC:                         1.104e+05
# Df Residuals:                      5375   BIC:                         1.104e+05
# Df Model:                             5
# Covariance Type:              nonrobust
# ...
#                          coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# ...

# %% [markdown]
# Mais uma vez, repetindo o passo anterior, retirando o year, pois a correlação já era muito baixa com o preço.

# %%
X_treinamento_restringido = dados_treinamento[['mileage_num(kmpl)','engine_num(CC)','max_power_num(bhp)', 'torque_num(Nm)']]
Y_treinamento = dados_treinamento['selling_price_dollar']

resultados_treinamento = regress(Y_treinamento,X_treinamento_restringido)
resultados_treinamento.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                              OLS Regression Results
# ...
# Dep. Variable:     selling_price_dollar   R-squared:                       0.590
# Model:                              OLS   Adj. R-squared:                  0.590
# Method:                   Least Squares   F-statistic:                     1938.
# Date:                  Tue, 24 Nov 2020   Prob (F-statistic):               0.00
# Time:                          14:08:11   Log-Likelihood:                -55173.
# No. Observations:                  5381   AIC:                         1.104e+05
# Df Residuals:                      5376   BIC:                         1.104e+05
# Df Model:                             4
# Covariance Type:              nonrobust
# ...
#                          coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# ...

# %% [markdown]
# Abaixo é feita a previsão final, usando apenas as variáveis relevantes para a previsão e aplicando a função `regress()` para que através do método da regressão linear, o nosso modelo prevê, usando as variáveis dependentes e sua correlação com o preço, qual será o preço predito para cada carro.

# %%
X_teste_restringido = dados_teste[['mileage_num(kmpl)','engine_num(CC)','max_power_num(bhp)', 'torque_num(Nm)']]
Y_teste = dados_teste[['selling_price_dollar']]
X_teste_completo = sm.add_constant(X_teste_restringido)
Y_previsto = resultados_treinamento.predict(X_teste_completo)
# Out:
# C:\Users\tprfe\AppData\Local\Continuum\anaconda3\lib\site-packages\numpy\core\fromnumeric.py:2389: FutureWarning: Method .ptp is deprecated and will be removed in a future version. Use numpy.ptp instead.
#   return ptp(axis=axis, out=out, **kwargs)

# %% [markdown]
# Abaixo foi plotado o gráfico de valores observador x valores previstos pelo nosso modelo, com a linha vermelha sendo a bissetriz, o que seria o ideal de acerto do modelo, 100%, no entanto, com os erros, evidentemente os pontos variam acima e abaixo da linha.

# %%
plt.scatter(Y_teste,Y_previsto)
plt.plot([0,80000],[0,80000], color='red') #bissetriz
plt.title('Valores previstos x valores observados')
plt.ylabel('Preço previsto (em dólar)')
plt.xlabel('Preço observado (em dólar)')
plt.xlim(0,80000)
plt.ylim(0,80000)
plt.show()

# %% [markdown]
# Relacionado ao gráfico anterior, abaixo está o erro absoluto de cada ponto, sendo o ideal uma linha reta no 0 (100% de acurácia), no entanto, o nosso modelo, com seus erros variou tanto ultrapassando o valor, quanto para menos.

# %%
a=[]
yu = np.arange(0,2307,1)
for i in range(2307):
    a.append(Y_previsto.iloc[i] - Y_teste.iloc[i])
plt.scatter(yu,a)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-1f5f3a03b269> in <module>
#       1 a=[]
# ----> 2 yu = np.arange(0,2307,1)
#       3 for i in range(2307):
#       4     a.append(Y_previsto.iloc[i] - Y_teste.iloc[i])
#       5 plt.scatter(yu,a)
#
# NameError: name 'np' is not defined

# %% [markdown]
# Score da regressão linear

# %% [markdown]
# Aqui temos a porcentagem de acerto do nosso modelo, definido pelo score

# %%
print(f"Score da regressão linar calculado por R^2 = {r2_score(Y_teste, Y_previsto)}")
# Out:
# Score da regressão linar calculado por R^2 = 0.588298564960718

# %% [markdown]
# ## Regression Tree
#
# Nas próximas células, iremos implementar um modelo de árvore de decisão. Uma árvore de decisão é uma das abordagens de modelagem preditiva usadas em estatística, mineração de dados e machine learning. Utiliza-se uma árvore de decisão como um modelo preditivo para partir de observações sobre uma variável independente (representado nos ramos) para conclusões sobre o valor alvo da base de dados (representado nas folhas). No caso de valores quantitativos, as árvores são chamadas de árvores de regressão. As árvores de decisão estão entre os algoritmos de aprendizado de máquina mais populares devido à sua flexibilidade e simplicidade de implementação.

# %%
# Fit regression model
regr_1 = DecisionTreeRegressor(max_depth = 4)
regr_2 = DecisionTreeRegressor(max_depth = 5)
regr_1.fit(Y_teste,Y_previsto)
regr_2.fit(Y_teste,Y_previsto)


# Predict
y_1 = regr_1.predict(Y_teste.values.reshape(-1, 1))
y_2 = regr_2.predict(Y_teste.values.reshape(-1, 1))

# Plot the results
plt.figure()
plt.scatter(Y_teste, y_1, label="data")
#plt.plot(Y_previsto, y_1, color="red", label="max_depth=2", linewidth=2)
#plt.plot(Y_previsto, y_2, color="yellowgreen", label="max_depth=5", linewidth=2)
plt.xlabel("data")
plt.ylabel("target")
plt.title("Decision Tree Regression")
plt.legend()
plt.show()
print(f"Score da regressão linar calculado por R^2 = {r2_score(Y_teste, y_1)}")

plt.figure()
plt.scatter(Y_teste, y_2, label="data")
#plt.plot(Y_previsto, y_1, color="red", label="max_depth=2", linewidth=2)
#plt.plot(Y_previsto, y_2, color="yellowgreen", label="max_depth=5", linewidth=2)
plt.xlabel("data")
plt.ylabel("target")
plt.title("Decision Tree Regression")
plt.legend()
plt.show()
print(f"Score da regressão linar calculado por R^2 = {r2_score(Y_teste, y_2)}")
# Out:
# '# Fit regression model\nregr_1 = DecisionTreeRegressor(max_depth = 2)\nregr_2 = DecisionTreeRegressor(max_depth = 5)\nregr_1.fit(Y_teste,Y_previsto)\nregr_2.fit(Y_teste,Y_previsto)\n\n# Predict\nX_test = np.arange(0.0, 80000.0, 1)[:, np.newaxis]\ny_1 = regr_1.predict(X_test)\ny_2 = regr_2.predict(X_test)\n\n# Plot the results\nplt.figure()\nplt.scatter(Y_teste, Y_previsto, label="data")\nplt.plot(X_test, y_1, color="red", label="max_depth=2", linewidth=2)\nplt.plot(X_test, y_2, color="yellowgreen", label="max_depth=5", linewidth=2)\nplt.xlabel("data")\nplt.ylabel("target")\nplt.title("Decision Tree Regression")\nplt.legend()\nplt.show()'

# %%
regr = DecisionTreeRegressor(max_depth=4)
model = regr.fit(Y_teste, y_1)
fig = plt.figure(figsize=(50,40))
_ = tree.plot_tree(regr,filled=True)

# %%
X = dados['selling_price']
Y = dados[['year', 'km_driven', 'mileage_num(kmpl)', 'engine_num(CC)', 'max_power_num(bhp)', 'torque_num(Nm)',
       'seats']]

# %%
clf = tree.DecisionTreeClassifier(random_state=0)
iris = load_iris()
plt.figure(figsize=(25,20))
clf = clf.fit(iris.data, iris.target)
tree.plot_tree(clf);

# %% [markdown]
#  **Critério de Divisão:RSS (soma residual dos quadrados)**
#
#  RSS é uma medida da discrepância entre os dados e um modelo de estimativa. Um pequeno RSS indica um ajuste perfeito do modelo aos dados.
#
# Vamos começar a construir a regression tree.
# O primeiro passo é feito através da implementação de um critério de divisão que é usado para decidir as features mais discriminadoras em cada etapa.
#
# RSS é calculado da maneira abaixo:
#
# $$RSS =\sum_{\text {left }}\left(y_{i}-\hat{y_{L}}\right)^{2}+\sum_{\text {right }}\left(y_{i}-\hat{y_{R}}\right)^{2}$$
#
# Em que $\hat{y_L} e \hat{y_r}$ são os valores médios dos nós esquerdo e direito.
#
# Para encontrar o "melhor" split, o objetivo é minimizar o RSS

# %%
def rss(y_left, y_right):
    def squared_residual_sum(y):
        return np.sum((y - np.mean(y)) ** 2)
    
    return squared_residual_sum(y_left) + squared_residual_sum(y_right)

# %% [markdown]
# Agora vamos plotar RSS de duas features com respeito a cada limite possível. Escolhemos as variáveis com maior e menor correlação com o preço do carro, como foi encontrado no heatmap: bhp e year.

# %%
def compute_rss_by_threshold(feature):
    features_rss = []
    thresholds = X_treinamento[feature].unique().tolist()
    thresholds.sort()
    thresholds = thresholds[1:]
    for t in thresholds:
        y_left_ix = X_treinamento[feature] < t
        y_left, y_right = Y_treinamento[y_left_ix], Y_treinamento[~y_left_ix]
        features_rss.append(rss(y_left, y_right))
    return thresholds, features_rss

# %%
bhp_thresholds, bhp_rss = compute_rss_by_threshold('max_power_num(bhp)')
year_thresholds, year_rss = compute_rss_by_threshold('year')

plt.figure(figsize=(12, 5))
plt.subplot(1, 2, 1)
plt.xlabel('Thresholds')
plt.ylabel('RSS')
plt.title('max_power_num(bhp) (Maior Correlação com o preço do carro)')
plt.plot(bhp_thresholds, bhp_rss)

plt.subplot(1, 2, 2)
plt.xlabel('Thresholds')
plt.ylabel('RSS')
plt.title('year (Menor Correlação com o preço do carro)')
plt.plot(year_thresholds, year_rss)

plt.tight_layout()
plt.show()

# %% [markdown]
# A função abaixo encontra o número de limtes ideal para minimizar o RSS para ambas as variáveis, vizualisado nos gráficos acima.

# %% [markdown]
# **Dividindo**
#
# Agora implementamos o procedimento de divisão recursiva como uma função. Encontramos as melhores regras e dividimos os dados de acordo. Armazenamos as regras em um dicionário. Por último, usamos uma função auxiliar para encontrar a melhor regra durante cada divisão.
#
# Chamamos a função para criar uma árvore com profundidade 3 e visualizar o resultado.

# %%
def find_best_rule(X_treinamento, Y_treinamento):
    best_feature, best_threshold, min_rss = None, None, np.inf
    for feature in X_treinamento.columns:
        thresholds = X_treinamento[feature].unique().tolist()
        thresholds.sort()
        thresholds = thresholds[1:]
        for t in thresholds:
            y_left_ix = X_treinamento[feature] < t
            y_left, y_right = Y_treinamento[y_left_ix], Y_treinamento[~y_left_ix]
            t_rss = rss(y_left, y_right)
            if t_rss < min_rss:
                min_rss = t_rss
                best_threshold = t
                best_feature = feature
    
    return {'feature': best_feature, 'threshold': best_threshold}

# %%
def split(X_treinamento, Y_treinamento, depth, max_depth):
    if depth == max_depth or len(X_treinamento) < 2:
        return {'prediction': np.mean(Y_treinamento)}
    
    rule = find_best_rule(X_treinamento, Y_treinamento)
    left_ix = X_treinamento[rule['feature']] < rule['threshold']
    rule['left'] = split(X_treinamento[left_ix], Y_treinamento[left_ix], depth + 1, max_depth)
    rule['right'] = split(X_treinamento[~left_ix], Y_treinamento[~left_ix], depth + 1, max_depth)
    return rule

rules = split(X_treinamento, Y_treinamento, 0, 3)

# %%
regr = DecisionTreeRegressor(max_depth=3, random_state=1234)
model = regr.fit(X_treinamento, Y_treinamento)
fig = plt.figure(figsize=(25,20))
_ = tree.plot_tree(regr,filled=True)

# %%
def predict(sample, rules):
    prediction = None
    while prediction is None:
        feature, threshold = rules['feature'], rules['threshold']
        if sample[feature] < threshold:
            rules = rules['left']
        else:
            rules = rules['right']
        prediction = rules.get('prediction', None)
    return prediction

# %% [markdown]
# **Avaliação**
#
# Avaliamos a árvore de regressão criando árvores em diferentes profundidades e medindo o $R^2$ na divisão teste.

# %%
def evaluate(X, Y):
    preds = X.apply(predict, axis='columns', rules=rules.copy())
    lista = []
    lista.append(preds)
    return r2_score(preds, Y), lista
lista = evaluate(X_teste, Y_teste)[1]
#print(lista)

# %%
for max_depth in range(3, 10):
    rules = split(X_treinamento,  Y_treinamento, 0, max_depth)
    train_r2 = evaluate(X_treinamento,  Y_treinamento)
    test_r2 = evaluate(X_teste, Y_teste)
    print('Max Depth', max_depth, 'Treinamento R2:', train_r2, 'Teste R2:',test_r2)

# %% [markdown]
# <div id="conclusao"></div>
#
# ## Conclusão

# %% [markdown]
# <div id="referencias"></div>
#
# ## Referêcias
#
# [1] - https://www.kaggle.com/nehalbirla/vehicle-dataset-from-cardekho?select=Car+details+v3.csv
#
# [2] - https://scikit-learn.org/stable/index.html
#
# [3] - https://scikit-learn.org/stable/modules/generated/sklearn.tree.DecisionTreeRegressor.html
#
# [4] - https://matplotlib.org/3.1.1/api/_as_gen/matplotlib.pyplot.html
#
# [5] - https://numpy.org/
#
# [6] - https://seaborn.pydata.org/
